# %%
import os
from ultralytics import YOLOE # type: ignore
from PIL.Image import Image as PILImage

import openvino.properties.hint as hints
from openvino import Core

# %%
model_id = "yoloe-11s-seg.pt"
models_dir = "/home/alicranck/almog/projects/Flash-Findr/models"

if not os.path.isfile(model_id):
    model_path = os.path.join(models_dir, model_id)
    model = YOLOE(model_path)
else:
    model = YOLOE(model_id)

# %%
core = Core()
config = {"PERFORMANCE_HINT": "THROUGHPUT",
          "NUM_STREAMS": 4,
          "DYN_BATCH_ENABLED": "YES"}

model.export(format="openvino", half=True, dynamic=True, batch=4)
export_xml_path = os.path.join(models_dir,
                                model_id.split(".")[0] + "_openvino_model",
                                    model_id.split(".")[0] + ".xml")
# openvino_model = core.compile_model(export_xml_path, "AUTO", config)

# %%
openvino_model

# %%
compiled_model_ul = YOLOE("/home/alicranck/almog/projects/Flash-Findr/models/yoloe-11s-seg_openvino_model")

# %%
compiled_model_ul.predict(["https://hips.hearstapps.com/hmg-prod/images/ferrari-e-suv-2-copy-680287cac36b2.jpg?crop=1.00xw:0.838xh;0,0.0673xh",
                           "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSzaza6RZif9EbWuM_ckYTt4natIUEGg8I-Sw&s"] * 2, batch=4)

# %%
import matplotlib.pyplot as plt


plt.imshow(res[0].plot())
