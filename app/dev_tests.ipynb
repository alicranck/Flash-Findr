# %%
import os, sys
import time
import yaml
from PIL.Image import Image as PILImage

sys.path.append("/home/almog_elharar/almog/Flash-Findr")

from app.ml_core.tools.detection import OpenVocabularyDetector
from app.ml_core.tools.captioning import Captioner
from app.api.engine import VideoInferenceEngine
# Out:
# Multiple distributions found for package optimum. Picked distribution: optimum-onnx
# /home/almog_elharar/.conda/envs/almog_dev_env/lib/python3.12/site-packages/openvino/runtime/__init__.py:10: DeprecationWarning: The `openvino.runtime` module is deprecated and will be removed in the 2026.0 release. Please replace `openvino.runtime` with `openvino`.
#   warnings.warn(

# %% [markdown]
# ## Test tools

# %% [markdown]
# ### Helpers

# %%
demo_video_url = ""


def time_run(tool):
    start_time = time.time()
    tool.run(demo_video_url)
    end_time = time.time()
    print(f"Time taken: {end_time - start_time} seconds")

# %% [markdown]
# ### Detector / Segmentor

# %%
cfg_path = "/home/almog_elharar/almog/Flash-Findr/app/ml_core/configs/ov_detection.yaml"
with open(cfg_path, 'r') as f:
    cfg = yaml.safe_load(f)

cfg["vocabulary"] = ["person", "car", "bus"]

detector = OpenVocabularyDetector(cfg['model'], cfg)

# %%
detector.model.names

# %% [markdown]
# ### Captioner

# %%
captioner = Captioner("/home/almog_elharar/almog/Flash-Findr/app/models/OVSmolVLM2-256M_video", {})
# Out:
# INFO: Loading Captioner with model: /home/almog_elharar/almog/Flash-Findr/app/models/OVSmolVLM2-256M_video...
# INFO: Captioner successfully loaded and warmed up on cpu.

# %%
data = captioner.process("/home/almog_elharar/almog/Flash-Findr/app/ferrari-e-suv-2-copy-680287cac36b2.jpg", {})
# Out:
# DETECTED Trigger for Captioner
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = captioner.process("/home/almog_elharar/almog/Flash-Findr/app/ferrari-e-suv-2-copy-680287cac36b2.jpg", {})
#
# File ~/almog/Flash-Findr/app/ml_core/tools/base_tool.py:124, in BaseVisionTool.process(self, frame_handle, data, context)
#     121         raw_output = self.inference(model_input)
#     123     self.last_result = raw_output
# --> 124     new_data = self.postprocess(raw_output, frame.shape)
#     125 else:
#     126     new_data = self.extrapolate_last(frame_handle)
#
# File ~/almog/Flash-Findr/app/ml_core/tools/captioning.py:62, in Captioner.postprocess(self, raw_output, original_shape)
#      61 def postprocess(self, raw_output: Any, original_shape: tuple) -> dict:
# ---> 62     parsed_output = self.tokenizer.parse_output(raw_output)
# ...

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("/home/almog_elharar/almog/Flash-Findr/app/models/OVSmolVLM2-256M_video")

# %%
tokenizer.parse_response(data['caption'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tokenizer.parse_response(data['caption'])
#
# File ~/.conda/envs/almog_dev_env/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1100, in SpecialTokensMixin.__getattr__(self, key)
#    1097         return self.convert_tokens_to_ids(attr_as_tokens) if attr_as_tokens is not None else None
#    1099 if key not in self.__dict__:
# -> 1100     raise AttributeError(f"{self.__class__.__name__} has no attribute {key}")
#    1101 else:
#    1102     return super().__getattr__(key)
#
# AttributeError: GPT2TokenizerFast has no attribute parse_response

# %%
import json

data['caption']

# %%
import time
